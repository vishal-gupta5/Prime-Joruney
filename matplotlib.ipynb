# %%
import matplotlib.pyplot as plt

# %%
X = [1, 2, 3,4, 5]
Y = [6, 7, 8, 9, 10]

plt.plot(X, Y) # Line Chart
plt.show() # Showing the Chart

# %%
# Real Data

# Oscar Winner Movies
oscar_movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232]

plt.plot(years, revenue) # Line Plot
plt.title("Oscar Movies revenue in each year")
plt.xlabel("Years")
plt.ylabel("Revenues (in $M)")
# Out:
# Text(0, 0.5, 'Revenues (in $M)')
