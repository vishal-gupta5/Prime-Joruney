# %%
import requests
# Out:
# Requirement already satisfied: lxml in C:\Users\Visha\anaconda3\Lib\site-packages (6.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
URL = "https://stephen-king-api.onrender.com/api/books"

res = requests.get(URL)

# %%
json_data = res.json();

# %%
import pandas as pd

df = pd.json_normalize(json_data["data"])

# %%
df[["id", "Title", "Year", "ISBN"]]
# Out:
#     id            Title  Year                  ISBN
# 0    1           Carrie  1974     978-0-385-08695-0
# 1    2      Salem's Lot  1975     978-0-385-00751-1
# 2    3      The Shining  1977     978-0-385-12167-5
# 3    4             Rage  1977     978-0-451-07645-8
# 4    5        The Stand  1978     978-0-385-12168-2
# ..  ..              ...   ...                   ...
# 59  60        Elevation  2018     978-1-98210-231-9
# 60  61    The Institute  2019     978-1-98211-056-7
# 61  62            Later  2021     978-1-78909-649-1
# 62  63    Billy Summers  2021     978-1-982-17361-6
# 63  72  The Roopak Zone  1979  978-0-670-26069697-5
#
# [64 rows x 4 columns]

# %%
URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

# %%
if res.status_code == 200:
    print(res.headers) 

with open("scraped_data/data1.html", "w", encoding="utf-8") as f:
        f.write(res.text)
# Out:
# {'Date': 'Mon, 21 Sep 2026 18:57:19 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=RxINTzvTtJ3X9GzJ45JjqpA8FDil5RGafHrZwxTgC%2Bs%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1790017039"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=RxINTzvTtJ3X9GzJ45JjqpA8FDil5RGafHrZwxTgC%2Bs%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1790017039"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': 'a3eb4b7fbf1b5f7b-SIN', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
# Beautifulsoup
from bs4 import BeautifulSoup

with open("scraped_data/data1.html", "r", encoding="utf-8") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "html.parser")

# %%
all_h3 = soup.find_all("h3")
all_countries = []

for h3 in all_h3:
    name = h3.get_text(strip=True)
    population = h3.find_next("div").select("span.country-population")[0].get_text(strip=True);

    all_countries.append([name, population]);

# %%
df = pd.DataFrame(all_countries)

# %%
df.to_csv("cleaned_data/data.csv", index=False)
